# %% [markdown]
# # 概览

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold

# 模型的包
from sklearn.linear_model import Perceptron,SGDClassifier,LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier

from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import BernoulliNB

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier


import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_rows',None)

# %%
train=pd.read_csv("./data/train.csv")#(891,12)
test=pd.read_csv("./data/test.csv")#(418,11)
train['is_train']=1
test['is_train']=0
data=pd.concat([train,test],ignore_index=True)

# %% [markdown]
# # 属性分析

# %% [markdown]
# ## 性别
# ### 只区分男女(仅分析)

# %%
sex_data=test[['PassengerId','Sex']]
sex_data['Survived']=sex_data['Sex'].apply(lambda x:1 if x=='female' else 0)

# %%
# 0.76555，只使用性别一个特征，这么简单粗暴，都能有这么高的准确率
sex_data[['PassengerId','Survived']].to_csv('result_20220611_sexModel.txt',index=False,header=True)

# %%
train[(train['Sex']=='female')&(train['Survived']==0)].head(10)# 死亡的female几乎都是低Pclass
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 49            50         0       3
# 71            72         0       3
# 100          101         0       3
# 111          112         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 71                          Goodwin, Miss. Lillian Amy  female  16.0      5
# 100                            Petranec, Miss. Matilda  female  28.0      0
# 111                               Zabour, Miss. Hileni  female  14.5      1
#
#      Parch   Ticket     Fare Cabin Embarked  is_train
# 14       0   350406   7.8542   NaN        S         1
# 18       0   345763  18.0000   NaN        S         1
# 24       1   349909  21.0750   NaN        S         1
# 38       0   345764  18.0000   NaN        S         1
# 40       0     7546   9.4750   NaN        S         1
# 41       0    11668  21.0000   NaN        S         1
# 49       0   349237  17.8000   NaN        S         1
# 71       2  CA 2144  46.9000   NaN        S         1
# 100      0   349245   7.8958   NaN        S         1
# 111      0     2665  14.4542   NaN        C         1

# %%
train.query("Sex=='male'&Survived==1")# 男性的存活好像更难预测一点
# Out:
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 21            22         1       2
# 23            24         1       1
# 36            37         1       3
# 55            56         1       1
# 65            66         1       3
# 74            75         1       3
# 78            79         1       2
# 81            82         1       3
# 97            98         1       1
# 107          108         1       3
# 125          126         1       3
# 127          128         1       3
# 146          147         1       3
# 165          166         1       3
# 183          184         1       2
# 187          188         1       1
# 193          194         1       2
# 204          205         1       3
# 207          208         1       3
# 209          210         1       1
# 220          221         1       3
# 224          225         1       1
# 226          227         1       2
# 248          249         1       1
# 261          262         1       3
# 267          268         1       3
# 271          272         1       3
# 283          284         1       3
# 286          287         1       3
# 288          289         1       2
# 298          299         1       1
# 301          302         1       3
# 305          306         1       1
# 338          339         1       3
# 340          341         1       2
# 348          349         1       3
# 370          371         1       1
# 390          391         1       1
# 391          392         1       3
# 400          401         1       3
# 407          408         1       2
# 414          415         1       3
# 429          430         1       3
# 430          431         1       1
# 444          445         1       3
# 445          446         1       1
# 447          448         1       1
# 449          450         1       1
# 755      1             250649   14.5000          NaN        S         1
# 762      0               2663    7.2292          NaN        C         1
# 788      2          C.A. 2315   20.5750          NaN        S         1
# 802      2             113760  120.0000      B96 B98        S         1
# 803      1               2625    8.5167          NaN        C         1
# 804      0             347089    6.9750          NaN        S         1
# 821      0             315098    8.6625          NaN        S         1
# 827      2    S.C./PARIS 2079   37.0042          NaN        C         1
# 828      0             367228    7.7500          NaN        Q         1
# 831      1              29106   18.7500          NaN        S         1
# 838      0               1601   56.4958          NaN        S         1
# 839      0              11774   29.7000          C47        C         1
# 857      0             113055   26.5500          E17        S         1
# 869      1             347742   11.1333          NaN        S         1
# 889      0             111369   30.0000         C148        C         1

# %%
train.query("Sex=='male'&Age<=18")# 15岁以下的男孩确实都叫master
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 78            79         1       2
# 86            87         0       3
# 125          126         1       3
# 138          139         0       3
# 144          145         0       2
# 163          164         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 175          176         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 204          205         1       3
# 220          221         1       3
# 228          229         0       2
# 261          262         1       3
# 266          267         0       3
# 278          279         0       3
# 282          283         0       3
# 305          306         1       1
# 333          334         0       3
# 340          341         1       2
# 348          349         1       3
# 352          353         0       3
# 371          372         0       3
# 385          386         0       2
# 386          387         0       3
# 407          408         1       2
# 424          425         0       3
# 433          434         0       3
# 445          446         1       1
# 480          481         0       3
# 489          490         1       3
# 500          501         0       3
# 505          506         0       1
# 532          533         0       3
# 549          550         1       2
# 550          551         1       1
# 574          575         0       3
# 675          676         0       3
# 683          684         0       3
# 686          687         0       3
# 688          689         0       3
# 721          722         0       3
# 731          732         0       3
# 746          747         0       3
# 751          752         1       3
# 755          756         1       2
# 757          758         0       2
# 764          765         0       3
# 775          776         0       3
# 787          788         0       3
# 788          789         1       3
# 791          792         0       2
# 802          803         1       1
# 803          804         1       3
# 819          820         0       3
# 824          825         0       3
# 827          828         1       2
# 831          832         1       2
# 834          835         0       3
# 841          842         0       2
# 844          845         0       3
# 850          851         0       3
# 869          870         1       3
#
#                                                 Name   Sex    Age  SibSp  \
# 7                     Palsson, Master. Gosta Leonard  male   2.00      3
# 16                              Rice, Master. Eugene  male   2.00      4
# 50                        Panula, Master. Juha Niilo  male   7.00      4
# 59                Goodwin, Master. William Frederick  male  11.00      5
# 63                             Skoog, Master. Harald  male   4.00      3
# 78                     Caldwell, Master. Alden Gates  male   0.83      0
# 86                            Ford, Mr. William Neal  male  16.00      1
# 125                     Nicola-Yarred, Master. Elias  male  12.00      1
# 138                              Osen, Mr. Olaf Elon  male  16.00      0
# 144                       Andrew, Mr. Edgardo Samuel  male  18.00      0
# 163                                  Calic, Mr. Jovo  male  17.00      0
# 164                     Panula, Master. Eino Viljami  male   1.00      4
# 165  Goldsmith, Master. Frank John William "Frankie"  male   9.00      0
# 775      0             347078    7.7500      NaN        S         1
# 787      1             382652   29.1250      NaN        Q         1
# 788      2          C.A. 2315   20.5750      NaN        S         1
# 791      0             239865   26.0000      NaN        S         1
# 802      2             113760  120.0000  B96 B98        S         1
# 803      1               2625    8.5167      NaN        C         1
# 819      2             347088   27.9000      NaN        S         1
# 824      1            3101295   39.6875      NaN        S         1
# 827      2    S.C./PARIS 2079   37.0042      NaN        C         1
# 831      1              29106   18.7500      NaN        S         1
# 834      0               2223    8.3000      NaN        S         1
# 841      0        S.O./P.P. 3   10.5000      NaN        S         1
# 844      0             315090    8.6625      NaN        S         1
# 850      2             347082   31.2750      NaN        S         1
# 869      1             347742   11.1333      NaN        S         1

# %% [markdown]
# ### 区分男孩

# %%
data['Title']=data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
data.loc[data['Title']=='Master','Sex']='boy'

# %% [markdown]
# ## 家族
# ### 不考虑保姆

# %%
data['Surname']=data['Name'].apply(lambda x:x.split(',')[0])

data["Ticket_id"]=(data['Pclass'].astype(str) + "-" + data['Ticket'].str[:-1].astype(str) + "-" + data['Fare'].astype(str) + "-" + data['Embarked'].astype(str) )
data["Group_id"] = data['Surname'] + "-" + data["Ticket_id"]

# 后续处理
data.loc[data['Sex'] == "male", "Group_id"] = "noGroup"
data["WC_count"] = (data.loc[data['Sex'] != "male"].groupby("Group_id")["Group_id"].transform("count"))
data.loc[data['WC_count'] <= 1, "Group_id"] = "noGroup"

data["WCSurvived"] = data.loc[data['Group_id'] != "noGroup"].groupby("Group_id").Survived.transform("mean")

# %%
data.loc[data['Sex'] != "male"].groupby("Group_id")["Group_id"]

# %%
data.loc[data['Sex'] != "male"].groupby("Group_id")["Group_id"].transform("count")
# Out:
# 1       306
# 2       306
# 3       306
# 7         5
# 8         3
# 9       306
# 10        3
# 11      306
# 14      306
# 15      306
# 16        6
# 18        2
# 19      306
# 22      306
# 24        5
# 25        6
# 28      306
# 31      306
# 32      306
# 38        2
# 39        2
# 40      306
# 41      306
# 43        3
# 44      306
# 47      306
# 49      306
# 50        4
# 52      306
# 53      306
# 56      306
# 58        3
# 59        6
# 61      306
# 63        5
# 65        3
# 66      306
# 68      306
# 71        6
# 78        2
# 79      306
# 82      306
# 84      306
# 85      306
# 88        4
# 98        2
# 100     306
# 106     306
# 109     306
# 111       2
# 113       2
# 114     306
# 119       6
# 123     306
# 125       2
# 128       3
# 132     306
# 133     306
# 136     306
# 140       3
# 141     306
# 142     306
# 147       3
# 151     306
# 156     306
# 159       7
# 161       2
# 164       4
# 165       2
# 166     306
# 167       5
# 171       6
# 172       3
# 176       5
# 177     306
# 180       7
# 182       6
# 183       4
# 184       2
# 186     306
# 190     306
# 192     306
# 193       2
# 194     306
# 195     306
# 198     306
# 199     306
# 205       2
# 208     306
# 211     306
# 215       2
# 216     306
# 218     306
# 229       5
# 230     306
# 233       6
# 235     306
# 237       2
# 240       2
# 241       2
# 246     306
# 247       2
# 251       2
# 254       2
# 255       3
# 256     306
# 257     306
# 258     306
# 259     306
# 261       6
# 910     306
# 912     306
# 913     306
# 915       4
# 917     306
# 923       3
# 924       3
# 927     306
# 928       2
# 934     306
# 935     306
# 939     306
# 940       3
# 943       2
# 944       4
# 946       6
# 950     306
# 954     306
# 955       4
# 956     306
# 957     306
# 960       4
# 961     306
# 963     306
# 965     306
# 968     306
# 970     306
# 971       3
# 977     306
# 978     306
# 979     306
# 980       3
# 981     306
# 983     306
# 987     306
# 989     306
# 991     306
# 995       2
# 1002    306
# 1003    306
# 1004    306
# 1005    306
# 1008      3
# 1010    306
# 1011      2
# 1013    306
# 1016    306
# 1018      2
# 1023      5
# 1029    306
# 1031      6
# 1032    306
# 1041    306
# 1044      2
# 1045      6
# 1047    306
# 1048    306
# 1050      3
# 1051    306
# 1052      3
# 1053    306
# 1056      2
# 1059    306
# 1060    306
# 1066      2
# 1067    306
# 1069      4
# 1070      2
# 1073    306
# 1075    306
# 1077    306
# 1079      7
# 1083      2
# 1085      2
# 1087      2
# 1088    306
# 1090    306
# 1091    306
# 1092      2
# 1094      3
# 1097    306
# 1099    306
# 1104    306
# 1105    306
# 1107    306
# 1109    306
# 1111      2
# 1113    306
# 1115    306
# 1116      3
# 1118    306
# 1122    306
# 1129    306
# 1130    306
# 1131    306
# 1132      2
# 1135      3
# 1137    306
# 1139    306
# 1140    306
# 1141      3
# 1149    306
# 1153      3
# 1154      2
# 1159    306
# 1163    306
# 1164    306
# 1166    306
# 1171      1
# 1172      3
# 1173    306
# 1174      3
# 1175      2
# 1182    306
# 1187      3
# 1195    306
# 1196    306
# 1198      2
# 1200    306
# 1204    306
# 1205    306
# 1206    306
# 1215    306
# 1217      4
# 1221      2
# 1224      2
# 1230    306
# 1234    306
# 1235      2
# 1236    306
# 1238    306
# 1240    306
# 1241    306
# 1245      3
# 1247    306
# 1250    306
# 1251      7
# 1252      2
# 1253    306
# 1255    306
# 1256      7
# 1258      1
# 1259      2
# 1262    306
# 1265      2
# 1266    306
# 1267    306
# 1270      6
# 1273    306
# 1274    306
# 1276      3
# 1280      5
# 1282      2
# 1283      2
# 1286    306
# 1288    306
# 1291    306
# 1293      2
# 1299    306
# 1300      3
# 1301    306
# 1302      2
# 1303    306
# 1305    306
# 1308      3
# Name: Group_id, dtype: int64

# %%
# female组内生存率为0时判断死亡
# boy组内生存率<=0.5时判断死亡
data.loc[(data['is_train']==0)&(data['Group_id']!="noGroup")&(data['Sex']=='female')&(data['WCSurvived']==0.00),'Survived']=0
data.loc[(data['is_train']==0)&(data['Group_id']!="noGroup")&(data['Sex']=='female')&(data['WCSurvived']!=0.00)&(data['WCSurvived'].notnull()),'Survived']=1
data.loc[(data['is_train']==0)&(data['Group_id']!="noGroup")&(data['Sex']=='boy')&((data['Pclass']!=3)|(data['WCSurvived']>0.5)),'Survived']=1
data.loc[(data['is_train']==0)&(data['Group_id']!="noGroup")&(data['Sex']=='boy')&(data['Pclass']==3)&(data['WCSurvived']<=0.5),'Survived']=0

# %%
# 如果家族人员全部在测试集里呢
groups_test = set(data[data['is_train']==0]['Group_id'].unique()) - set(data[data['is_train']==1]['Group_id'].unique())
# data.loc[data['Group_id'].isin(groups_test)].sort_values(by="Surname")
data.loc[data['Group_id'].isin(groups_test),'Survived']=1
data.loc[data['Group_id']=='van Billiard-3-A/5. 85-14.5-S','Survived']=0

# %%
data.loc[(data['Group_id']=='noGroup')&(data['Sex'].isin(['male','boy'])),'Survived']=0
data.loc[(data['Group_id']=='noGroup')&(data['Sex']=='female'),'Survived']=1

# %%
data.loc[(data['is_train']==0)&(data['Group_id']=='noGroup'),'PassengerId']
# Out:
# 891      892
# 892      893
# 893      894
# 894      895
# 896      897
# 897      898
# 898      899
# 899      900
# 900      901
# 901      902
# 902      903
# 903      904
# 904      905
# 905      906
# 906      907
# 907      908
# 908      909
# 910      911
# 911      912
# 912      913
# 913      914
# 914      915
# 916      917
# 917      918
# 918      919
# 919      920
# 920      921
# 921      922
# 922      923
# 925      926
# 926      927
# 927      928
# 929      930
# 930      931
# 931      932
# 932      933
# 933      934
# 934      935
# 935      936
# 936      937
# 937      938
# 938      939
# 939      940
# 941      942
# 942      943
# 945      946
# 947      948
# 948      949
# 949      950
# 950      951
# 951      952
# 952      953
# 953      954
# 954      955
# 956      957
# 957      958
# 958      959
# 959      960
# 961      962
# 962      963
# 963      964
# 964      965
# 965      966
# 966      967
# 967      968
# 968      969
# 969      970
# 970      971
# 972      973
# 973      974
# 974      975
# 975      976
# 976      977
# 977      978
# 978      979
# 979      980
# 981      982
# 982      983
# 983      984
# 984      985
# 985      986
# 986      987
# 987      988
# 988      989
# 989      990
# 990      991
# 991      992
# 992      993
# 993      994
# 994      995
# 996      997
# 997      998
# 998      999
# 999     1000
# 1000    1001
# 1001    1002
# 1002    1003
# 1003    1004
# 1004    1005
# 1005    1006
# 1006    1007
# 1007    1008
# 1009    1010
# 1010    1011
# 1012    1013
# 1013    1014
# 1014    1015
# 1015    1016
# 1016    1017
# 1017    1018
# 1019    1020
# 1020    1021
# 1021    1022
# 1022    1023
# 1024    1025
# 1025    1026
# 1026    1027
# 1027    1028
# 1028    1029
# 1029    1030
# 1030    1031
# 1032    1033
# 1033    1034
# 1034    1035
# 1035    1036
# 1036    1037
# 1037    1038
# 1038    1039
# 1039    1040
# 1040    1041
# 1041    1042
# 1042    1043
# 1043    1044
# 1046    1047
# 1047    1048
# 1048    1049
# 1049    1050
# 1051    1052
# 1053    1054
# 1054    1055
# 1055    1056
# 1057    1058
# 1058    1059
# 1059    1060
# 1060    1061
# 1061    1062
# 1062    1063
# 1063    1064
# 1064    1065
# 1065    1066
# 1067    1068
# 1068    1069
# 1071    1072
# 1072    1073
# 1073    1074
# 1074    1075
# 1075    1076
# 1076    1077
# 1077    1078
# 1078    1079
# 1080    1081
# 1081    1082
# 1082    1083
# 1084    1085
# 1086    1087
# 1088    1089
# 1089    1090
# 1090    1091
# 1091    1092
# 1093    1094
# 1095    1096
# 1096    1097
# 1097    1098
# 1098    1099
# 1099    1100
# 1100    1101
data.loc[data['PassengerId'].isin([1172,1259]),"Group_id"] = data.loc[data['PassengerId'].isin([1172,1259]),'Surname'] + "-" + data.loc[data['PassengerId'].isin([1172,1259]),"Ticket_id"]

data.loc[data['PassengerId'].isin([1172,1259])]
# Out:
#       PassengerId  Survived  Pclass  \
# 1171         1172       0.0       3
# 1258         1259       0.0       3
#
#                                               Name     Sex   Age  SibSp  \
# 1171                        Oreskovic, Miss. Jelka  female  23.0      0
# 1258  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0
#
#       Parch   Ticket     Fare Cabin Embarked  is_train Title     Surname  \
# 1171      0   315085   8.6625   NaN        S         0  Miss   Oreskovic
# 1258      0  3101295  39.6875   NaN        S         0  Miss  Riihivouri
#
#                Ticket_id                       Group_id  WC_count  WCSurvived
# 1171    3-31508-8.6625-S     Oreskovic-3-31508-8.6625-S       1.0         NaN
# 1258  3-310129-39.6875-S  Riihivouri-3-310129-39.6875-S       1.0         NaN

# %%
# 别运行
data['Survived']=data['Survived'].astype('int64')
data.loc[data['is_train']==0,["PassengerId","Survived"]].to_csv('result_20220616_WCGModel_3.txt',index=False,header=True)

# %% [markdown]
# ### 考虑保姆(仅分析)

# %%
single_women_ticketId=set(data[(data['Sex']=='female')&(data['Group_id']=='noGroup')&(data['SibSp']+data['Parch']==0)]['Ticket_id'])
group_ticketId=set(data[data['Group_id']!='noGroup']['Ticket_id'])
babysitter_ticketId=group_ticketId.intersection(single_women_ticketId)

# %%
data[(data['Sex']=='female')&(data['Group_id']=='noGroup')&(data['Ticket_id'].isin(babysitter_ticketId))].sort_values(by='Ticket_id')
# Out:
#       PassengerId  Survived  Pclass  \
# 708           709         1       1
# 1032         1033         1       1
# 337           338         1       1
# 1262         1263         1       1
# 1291         1292         1       1
# 950           951         1       1
# 1266         1267         1       1
# 1067         1068         1       2
# 1258         1259         1       3
# 1171         1172         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 708                           Cleaver, Miss. Alice  female  22.0      0
# 1032                          Daniels, Miss. Sarah  female  33.0      0
# 337                Burns, Miss. Elizabeth Margaret  female  41.0      0
# 1262                     Wilson, Miss. Helen Alice  female  31.0      0
# 1291                       Bonnell, Miss. Caroline  female  30.0      0
# 950                    Chaudanson, Miss. Victorine  female  36.0      0
# 1266                      Bowen, Miss. Grace Scott  female  45.0      0
# 1067                          Sincock, Miss. Maude  female  20.0      0
# 1258  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0
# 1171                        Oreskovic, Miss. Jelka  female  23.0      0
#
#       Parch      Ticket      Fare    Cabin Embarked  is_train Title  \
# 708       0      113781  151.5500      NaN        S         1  Miss
# 1032      0      113781  151.5500      NaN        S         0  Miss
# 337       0       16966  134.5000      E40        C         1  Miss
# 1262      0       16966  134.5000  E39 E41        C         0  Miss
# 1291      0       36928  164.8667       C7        S         0  Miss
# 950       0    PC 17608  262.3750      B61        C         0  Miss
# 1266      0    PC 17608  262.3750      NaN        C         0  Miss
# 1067      0  C.A. 33112   36.7500      NaN        S         0  Miss
# 1258      0     3101295   39.6875      NaN        S         0  Miss
# 1171      0      315085    8.6625      NaN        S         0  Miss
#
#          Surname            Ticket_id Group_id  WC_count  WCSurvived
# 708      Cleaver     1-11378-151.55-S  noGroup       1.0         NaN
# 1032     Daniels     1-11378-151.55-S  noGroup       1.0         NaN
# 337        Burns       1-1696-134.5-C  noGroup       1.0         NaN
# 1262      Wilson       1-1696-134.5-C  noGroup       1.0         NaN
# 1291     Bonnell    1-3692-164.8667-S  noGroup       1.0         NaN
# 950   Chaudanson  1-PC 1760-262.375-C  noGroup       1.0         NaN
# 1266       Bowen  1-PC 1760-262.375-C  noGroup       1.0         NaN
# 1067     Sincock  2-C.A. 3311-36.75-S  noGroup       1.0         NaN
# 1258  Riihivouri   3-310129-39.6875-S  noGroup       1.0         NaN
# 1171   Oreskovic     3-31508-8.6625-S  noGroup       1.0         NaN

# %%
data[(data['Sex']!='male')&(data['Ticket_id'].isin(babysitter_ticketId))].sort_values(by=['Ticket_id','Surname','is_train'])
# Out:
#       PassengerId  Survived  Pclass  \
# 297           298       0.0       1
# 305           306       1.0       1
# 498           499       0.0       1
# 708           709       1.0       1
# 1032         1033       1.0       1
# 337           338       1.0       1
# 1087         1088       1.0       1
# 319           320       1.0       1
# 1262         1263       1.0       1
# 1291         1292       1.0       1
# 318           319       1.0       1
# 856           857       1.0       1
# 1266         1267       1.0       1
# 950           951       1.0       1
# 915           916       1.0       1
# 955           956       1.0       1
# 311           312       1.0       1
# 742           743       1.0       1
# 1221         1222       1.0       2
# 549           550       1.0       2
# 1067         1068       1.0       2
# 50             51       0.0       3
# 164           165       0.0       3
# 638           639       0.0       3
# 824           825       0.0       3
# 1258         1259       1.0       3
# 2               3       1.0       3
# 816           817       1.0       3
# 216           217       1.0       3
# 909           910       0.0       3
# 729           730       0.0       3
#
#                                                    Name     Sex    Age  SibSp  \
# 297                        Allison, Miss. Helen Loraine  female   2.00      1
# 305                      Allison, Master. Hudson Trevor     boy   0.92      1
# 498     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 708                                Cleaver, Miss. Alice  female  22.00      0
# 1032                               Daniels, Miss. Sarah  female  33.00      0
# 337                     Burns, Miss. Elizabeth Margaret  female  41.00      0
# 1087                    Spedden, Master. Robert Douglas     boy   6.00      0
# 319   Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.00      1
# 1262                          Wilson, Miss. Helen Alice  female  31.00      0
# 1291                            Bonnell, Miss. Caroline  female  30.00      0
# 318                            Wick, Miss. Mary Natalie  female  31.00      0
# 856          Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.00      1
# 1266                           Bowen, Miss. Grace Scott  female  45.00      0
# 950                         Chaudanson, Miss. Victorine  female  36.00      0
# 915     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.00      1
# 955                         Ryerson, Master. John Borie     boy  13.00      2
# 311                          Ryerson, Miss. Emily Borie  female  18.00      2
# 742               Ryerson, Miss. Susan Parker "Suzette"  female  21.00      2
#
# 311     Miss     Ryerson        1-PC 17-262.375-C
# 742     Miss     Ryerson        1-PC 17-262.375-C
# 1221     Mrs      Davies        2-C.A. 33-36.75-S
# 549   Master      Davies        2-C.A. 33-36.75-S
# 1067    Miss     Sincock        2-C.A. 33-36.75-S
# 50    Master      Panula         3-3101-39.6875-S
# 164   Master      Panula         3-3101-39.6875-S
# 638      Mrs      Panula         3-3101-39.6875-S
# 824   Master      Panula         3-3101-39.6875-S
# 1258    Miss  Riihivouri         3-3101-39.6875-S
# 2       Miss   Heikkinen  3-STON/O2. 3101-7.925-S
# 816     Miss    Heininen  3-STON/O2. 3101-7.925-S
# 216     Miss    Honkanen  3-STON/O2. 3101-7.925-S
# 909     Miss  Ilmakangas  3-STON/O2. 3101-7.925-S
# 729     Miss  Ilmakangas  3-STON/O2. 3101-7.925-S
#
#                                 Group_id  WC_count  WCSurvived
# 297               Allison-1-113-151.55-S       3.0    0.333333
# 305               Allison-1-113-151.55-S       3.0    0.333333
# 498               Allison-1-113-151.55-S       3.0    0.333333
# 708                              noGroup       1.0         NaN
# 1032                             noGroup       1.0         NaN
# 337                              noGroup       1.0         NaN
# 1087                Spedden-1-16-134.5-C       2.0    1.000000
# 319                 Spedden-1-16-134.5-C       2.0    1.000000
# 1262                             noGroup       1.0         NaN
# 1291                             noGroup       1.0         NaN
# 318                 Wick-1-36-164.8667-S       2.0    1.000000
# 856                 Wick-1-36-164.8667-S       2.0    1.000000
# 1266                             noGroup       1.0         NaN
# 950                              noGroup       1.0         NaN
# 915            Ryerson-1-PC 17-262.375-C       4.0    1.000000
# 955            Ryerson-1-PC 17-262.375-C       4.0    1.000000
# 311            Ryerson-1-PC 17-262.375-C       4.0    1.000000
# 742            Ryerson-1-PC 17-262.375-C       4.0    1.000000
# 1221            Davies-2-C.A. 33-36.75-S       2.0    1.000000
# 549             Davies-2-C.A. 33-36.75-S       2.0    1.000000
# 1067                             noGroup       1.0         NaN
# 50               Panula-3-3101-39.6875-S       4.0    0.000000
# 164              Panula-3-3101-39.6875-S       4.0    0.000000
# 638              Panula-3-3101-39.6875-S       4.0    0.000000
# 824              Panula-3-3101-39.6875-S       4.0    0.000000
# 1258                             noGroup       1.0         NaN
# 2                                noGroup       1.0         NaN
# 816                              noGroup       1.0         NaN
# 216                              noGroup       1.0         NaN
# 909   Ilmakangas-3-STON/O2. 3101-7.925-S       2.0    0.000000
# 729   Ilmakangas-3-STON/O2. 3101-7.925-S       2.0    0.000000

# %% [markdown]
# # 非WCG正常流程

# %% [markdown]
# ## 数据预处理

# %%
def getAgeRange(x):
    if 0<=x<16:return 1
    elif 16<=x<40:return 2
    else: return 3
data['Age_range']=data['Age'].apply(getAgeRange)

data['SexPclass']=data['Sex'].str.cat(data['Pclass'].map(lambda x:str(x)))

# %%
data['Fare']=data['Fare'].fillna(data['Fare'].median())# 有一个空值，中位数填充

data['Embarked']=data['Embarked'].fillna("S")# 就2个缺失值，填充了众数

# Cabin只有204个非空值
data['Cabins']=data['Cabin'].apply(lambda x:2 if len(str(x))>4 else(1 if pd.notna(x) else 0) )
data['Cabin']=data['Cabin'].str[:1]
data['Cabin']=data['Cabin'].fillna("Z")

# ticket比较复杂，先算了
# train['Ticket'].apply(lambda x:x.split(" ")[0]).value_counts()

data['Title']=data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
data['Title'] = data['Title'].replace(['Lady', 'Countess','Capt','Don','Col','Dr','Rev', 'Major', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
data['Title'] = data['Title'].replace('Mlle', 'Miss')
data['Title'] = data['Title'].replace('Ms', 'Miss')
data['Title'] = data['Title'].replace('Mme', 'Mrs')

data['familyNum']=data['SibSp']+data['Parch']
data['has_family']=data['familyNum'].apply(lambda x:1 if x>0 else 0)

data=data.drop(['Name','Ticket'],axis=1)

# %%
for col in ['Cabin','Embarked','Title','Sex','Age_range']:
    df=pd.get_dummies(data[col],sparse=True)
    for c in df.columns:
        df.rename(columns={c:col+str(c)},inplace=True)
    if col!='Sex':
        data=pd.concat([data.drop([col],axis=1),df],axis=1)
    
df=pd.get_dummies(data['SexPclass'],sparse=True)
data=pd.concat([data.drop(['SexPclass'],axis=1),df],axis=1)

# data=data.drop(['CabinA','CabinD','CabinF','CabinG','CabinT','Sexmale'],axis=1)

# %%
data=data.drop(['Surname','Ticket_id'],axis=1)

# %% [markdown]
# ### 预测测试集是否生存，用来填充缺失值

# %%
X_train=np.array(data[(data['is_train']==1)&(data['Sex']=='male')].drop(['Survived','is_train','Group_id','PassengerId','boy1','boy2','boy3','female1','female2','female3','Sex'],axis=1))
y_train=np.array(data[(data['is_train']==1)&(data['Sex']=='male')]['Survived'])
X_test=np.array(data[(data['is_train']==0)&(data['Sex']=='male')].drop(['Survived','is_train','Group_id','PassengerId','boy1','boy2','boy3','female1','female2','female3','Sex'],axis=1))

# %%
from lightgbm import LGBMClassifier

best_model=None
folds=5
avg_score=0
avg_ccore_train=0
best_score=0
result=np.zeros(245)# 245是测试集男性数量，418是测试集数量

kf=KFold(n_splits=folds,shuffle=True,random_state=2022)
for i, (train_index,test_index) in enumerate(kf.split(X_train)):
    lgb=LGBMClassifier(learning_rate=0.07,max_depth=20,n_estimators=70)
    lgb.fit(X_train[train_index],y_train[train_index])
    
    score_train=lgb.score(X_train[train_index],y_train[train_index])
    score=lgb.score(X_train[test_index],y_train[test_index])
    print('{}th fold train：{:.3f}, test：{:.3f}'.format(i,score_train,score))
    if best_score<score:
        best_score=score
        best_model=lgb    
    avg_score+=score
    avg_ccore_train+=score_train
    result+=lgb.predict(X_test)
avg_score/=folds
avg_ccore_train/=folds
result/=folds

print("avg train score= {:.3f}, avg score={:.3f}".format(avg_ccore_train,avg_score))
# Out:
# 0th fold train：1.000, test：1.000
# 1th fold train：1.000, test：1.000
# 2th fold train：1.000, test：1.000
# 3th fold train：1.000, test：1.000
# 4th fold train：1.000, test：1.000
# avg train score= 1.000, avg score=1.000

# %% [markdown]
# ### age缺失值填充
# #### 用lgb预测

# %%
data_age=data[(data['Age'].notnull())&(data['Sex']=='male')].drop(['Sex'],axis=1)
data_noAge=data[(data['Age'].isnull())&(data['Sex']=='male')].drop(['Sex'],axis=1)

X_train_age=np.array(data_age.drop(['is_train','Age','Group_id'],axis=1))
y_train_age=np.array(data_age['Age'])
X_test_age=np.array(data_noAge.drop(['is_train','Age','Group_id'],axis=1))

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error

best_model=None
folds=5
avg_score=0
best_score=0

kf=KFold(n_splits=folds,shuffle=True,random_state=2022)
for i, (train_index,test_index) in enumerate(kf.split(X_train_age)):
    lgb=LGBMRegressor(learning_rate=0.5,max_depth=5,n_estimators=7)
    lgb.fit(X_train_age[train_index],y_train_age[train_index])
    
    
    pred=lgb.predict(X_train_age[train_index])
    score0=mean_squared_error(pred,y_train_age[train_index])
    print(i,'th fold 0：',score0)
    
    pred=lgb.predict(X_train_age[test_index])
    score=mean_squared_error(pred,y_train_age[test_index])
    print(i,'th fold：',score)
    if best_score<score:
        best_score=score
        best_model=lgb    
    avg_score+=score
avg_score/=folds

print("avg score= ",avg_score)
# Out:
# 0 th fold 0： 31.70581316125064
# 0 th fold： 65.93150284010459
# 1 th fold 0： 32.790739317523744
# 1 th fold： 53.54091396135594
# 2 th fold 0： 35.67452811228919
# 2 th fold： 47.75250319877265
# 3 th fold 0： 34.415291439913304
# 3 th fold： 49.390923942970545
# 4 th fold 0： 37.20511378054557
# 4 th fold： 40.10425655256781
# avg score=  51.34402009915431

# %%
age_pred=best_model.predict(X_test_age)
data.loc[(data['Age'].isnull())&(data['Sex']=='male'),'Age']=age_pred

# %% [markdown]
# ## 模型训练

# %%
# 仅预测非WCG人
X_train=np.array(data[(data['is_train']==1)&(data['Sex']=='male')].drop(['Survived','is_train','Group_id','PassengerId','WC_count','WCSurvived','Sex'],axis=1))# (891, 42)
y_train=np.array(data[(data['is_train']==1)&(data['Sex']=='male')]['Survived'])# (891,)
X_test=np.array(data[(data['is_train']==0)&(data['Sex']=='male')&(data['Group_id']=='noGroup')].drop(['Survived','is_train','Group_id','PassengerId','WC_count','WCSurvived','Sex'],axis=1))# (351, 42)

# %%
# 模型函数
def train_model(model,params,X_train,y_train,X_test):
    folds=5
    train_Acc,valid_Acc=0,0
    train_pred,test_pred=np.zeros(537),np.zeros(245)#418所有人。351非wcg.537非wcg训练 891

    kf=StratifiedKFold(n_splits=folds,shuffle=True,random_state=2022)
    model.set_params(**params)
    for i, (train_index,valid_index) in enumerate(kf.split(X_train,y_train)):
        model.fit(X_train[train_index],y_train[train_index])

        train_score=model.score(X_train[train_index],y_train[train_index])
        valid_score=model.score(X_train[valid_index],y_train[valid_index])
        print('{}th fold train：{:.3f}, valid：{:.3f}'.format(i,train_score,valid_score))

        valid_Acc+=valid_score
        train_Acc+=train_score
        try:
            test_pred+=model.predict_proba(X_test)[:,1]
            train_pred[valid_index]=model.predict_proba(X_train[valid_index])[:,1]
        except:
            test_pred+=model.predict(X_test)
            train_pred[valid_index]=model.predict(X_train[valid_index])

    valid_Acc/=folds
    train_Acc/=folds
    test_pred/=folds
    print("avg train score= {:.3f}, avg valid score={:.3f}".format(train_Acc,valid_Acc))
    
    return train_pred,test_pred,valid_Acc

# %%
model=LGBMClassifier()
params={"learning_rate":0.07,"max_depth":12,"n_estimators":80}
train_pred_lgb,test_pred_lgb,valid_acc_lgb=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：1.000, valid：1.000
# 1th fold train：1.000, valid：1.000
# 2th fold train：1.000, valid：1.000
# 3th fold train：1.000, valid：1.000
# 4th fold train：1.000, valid：1.000
# avg train score= 1.000, avg valid score=1.000

# %%
model=XGBClassifier()
params={"learning_rate":0.05,"max_depth":16,"n_estimators":73}
train_pred_xgb,test_pred_xgb,valid_acc_xgb=train_model(model,params,X_train,y_train,X_test)
# Out:
# [22:27:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0th fold train：0.994, valid：0.966
# [22:27:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1th fold train：0.994, valid：0.961
# [22:27:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 2th fold train：0.992, valid：0.966
# [22:27:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 3th fold train：0.992, valid：0.966
# [22:27:34] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 4th fold train：0.992, valid：0.983
# avg train score= 0.993, avg valid score=0.969

# %%
model=CatBoostClassifier()
params={"learning_rate":0.08,"n_estimators":82}
train_pred_cat,test_pred_cat,valid_acc_cat=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0:	learn: 0.5432644	total: 165ms	remaining: 13.4s
# 1:	learn: 0.4244849	total: 166ms	remaining: 6.65s
# 2:	learn: 0.3403129	total: 167ms	remaining: 4.4s
# 3:	learn: 0.2735731	total: 168ms	remaining: 3.28s
# 4:	learn: 0.2403160	total: 169ms	remaining: 2.61s
# 5:	learn: 0.2086007	total: 170ms	remaining: 2.16s
# 6:	learn: 0.1800217	total: 172ms	remaining: 1.84s
# 7:	learn: 0.1635358	total: 173ms	remaining: 1.6s
# 8:	learn: 0.1440216	total: 174ms	remaining: 1.41s
# 9:	learn: 0.1344222	total: 175ms	remaining: 1.26s
# 10:	learn: 0.1250736	total: 176ms	remaining: 1.14s
# 11:	learn: 0.1151375	total: 189ms	remaining: 1.1s
# 12:	learn: 0.1070586	total: 190ms	remaining: 1.01s
# 13:	learn: 0.1012418	total: 191ms	remaining: 929ms
# 14:	learn: 0.0965195	total: 193ms	remaining: 860ms
# 15:	learn: 0.0927579	total: 194ms	remaining: 799ms
# 16:	learn: 0.0883815	total: 195ms	remaining: 745ms
# 17:	learn: 0.0839436	total: 196ms	remaining: 697ms
# 18:	learn: 0.0816500	total: 197ms	remaining: 654ms
# 19:	learn: 0.0793390	total: 198ms	remaining: 615ms
# 20:	learn: 0.0773612	total: 200ms	remaining: 580ms
# 21:	learn: 0.0760449	total: 201ms	remaining: 548ms
# 22:	learn: 0.0743600	total: 202ms	remaining: 519ms
# 23:	learn: 0.0718806	total: 204ms	remaining: 493ms
# 24:	learn: 0.0688395	total: 205ms	remaining: 468ms
# 25:	learn: 0.0680124	total: 206ms	remaining: 445ms
# 26:	learn: 0.0673890	total: 208ms	remaining: 423ms
# 27:	learn: 0.0645067	total: 209ms	remaining: 402ms
# 28:	learn: 0.0629601	total: 210ms	remaining: 383ms
# 67:	learn: 0.0413152	total: 133ms	remaining: 27.4ms
# 68:	learn: 0.0408413	total: 134ms	remaining: 25.3ms
# 69:	learn: 0.0405519	total: 136ms	remaining: 23.3ms
# 70:	learn: 0.0400763	total: 137ms	remaining: 21.2ms
# 71:	learn: 0.0397642	total: 138ms	remaining: 19.2ms
# 72:	learn: 0.0393669	total: 139ms	remaining: 17.2ms
# 73:	learn: 0.0381302	total: 141ms	remaining: 15.2ms
# 74:	learn: 0.0372162	total: 142ms	remaining: 13.2ms
# 75:	learn: 0.0363539	total: 143ms	remaining: 11.3ms
# 76:	learn: 0.0361765	total: 144ms	remaining: 9.37ms
# 77:	learn: 0.0357413	total: 146ms	remaining: 7.47ms
# 78:	learn: 0.0353001	total: 147ms	remaining: 5.58ms
# 79:	learn: 0.0346085	total: 148ms	remaining: 3.7ms
# 80:	learn: 0.0344089	total: 149ms	remaining: 1.84ms
# 81:	learn: 0.0341865	total: 151ms	remaining: 0us
# 4th fold train：0.997, valid：0.989
# avg train score= 0.997, avg valid score=0.969

# %%
model=GradientBoostingClassifier()
params={"learning_rate":0.11,"n_estimators":222}
train_pred_gbt,test_pred_gbt,valid_acc_gbt=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：1.000, valid：0.961
# 1th fold train：1.000, valid：0.949
# 2th fold train：1.000, valid：0.972
# 3th fold train：1.000, valid：0.966
# 4th fold train：1.000, valid：0.978
# avg train score= 1.000, avg valid score=0.965

# %%
model=RandomForestClassifier()
params={"n_estimators":150,"max_depth":4,"min_samples_split":5,"min_samples_leaf":3}
train_pred_rf,test_pred_rf,valid_acc_rf=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.971, valid：0.955
# 1th fold train：0.971, valid：0.966
# 2th fold train：0.971, valid：0.978
# 3th fold train：0.973, valid：0.961
# 4th fold train：0.965, valid：0.978
# avg train score= 0.970, avg valid score=0.967

# %%
model=LogisticRegression()
params={}
train_pred_lr,test_pred_lr,valid_acc_lr=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.968, valid：0.961
# 1th fold train：0.975, valid：0.955
# 2th fold train：0.969, valid：0.972
# 3th fold train：0.972, valid：0.966
# 4th fold train：0.971, valid：0.983
# avg train score= 0.971, avg valid score=0.967

# %%
model=LinearSVC()
params={"C":0.12,"tol":1e-4,"max_iter":1000}
train_pred_svc,test_pred_svc,valid_acc_svc=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.969, valid：0.961
# 1th fold train：0.975, valid：0.955
# 2th fold train：0.969, valid：0.972
# 3th fold train：0.972, valid：0.966
# 4th fold train：0.966, valid：0.978
# avg train score= 0.970, avg valid score=0.966

# %%
model=KNeighborsClassifier()
params={"n_neighbors":15,"p":1}
train_pred_knn,test_pred_knn,valid_acc_knn=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.920, valid：0.877
# 1th fold train：0.913, valid：0.882
# 2th fold train：0.910, valid：0.938
# 3th fold train：0.909, valid：0.910
# 4th fold train：0.927, valid：0.904
# avg train score= 0.916, avg valid score=0.902

# %%
model=Perceptron()
params={"penalty":'l2',"alpha":1e-5,"max_iter":19,"validation_fraction":0.1,"n_iter_no_change":10,"warm_start":True}
train_pred_pt,test_pred_pt,valid_acc_pt=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.920, valid：0.916
# 1th fold train：0.942, valid：0.916
# 2th fold train：0.948, valid：0.961
# 3th fold train：0.864, valid：0.854
# 4th fold train：0.934, valid：0.927
# avg train score= 0.922, avg valid score=0.915

# %%
model=SGDClassifier()
params={"loss":'log',"alpha":1e-4,"max_iter":20,"validation_fraction":0.1,"n_iter_no_change":10,"warm_start":True}
train_pred_sgd,test_pred_sgd,valid_acc_sgd=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.914, valid：0.894
# 1th fold train：0.924, valid：0.944
# 2th fold train：0.947, valid：0.961
# 3th fold train：0.955, valid：0.944
# 4th fold train：0.947, valid：0.938
# avg train score= 0.937, avg valid score=0.936

# %%
model=GaussianProcessClassifier()
params={}
train_pred_gp,test_pred_gp,valid_acc_gp=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：1.000, valid：0.816
# 1th fold train：1.000, valid：0.860
# 2th fold train：1.000, valid：0.860
# 3th fold train：1.000, valid：0.837
# 4th fold train：1.000, valid：0.820
# avg train score= 1.000, avg valid score=0.838

# %%
model=BernoulliNB()
params={"alpha":20}
train_pred_by,test_pred_by,valid_acc_by=train_model(model,params,X_train,y_train,X_test)
# Out:
# 0th fold train：0.930, valid：0.933
# 1th fold train：0.930, valid：0.933
# 2th fold train：0.927, valid：0.944
# 3th fold train：0.935, valid：0.910
# 4th fold train：0.930, valid：0.933
# avg train score= 0.930, avg valid score=0.930

# %%
result1=(test_pred_lgb+test_pred_xgb+test_pred_cat+test_pred_gbt+test_pred_rf+test_pred_lr+test_pred_svc\
         +test_pred_knn+test_pred_pt+test_pred_sgd+test_pred_gp+test_pred_by)/12

result1_round=np.round(result1)
data.loc[(data['is_train']==0)&(data['Group_id']=='noGroup'),'Survived']=result1_round
data['Survived']=data['Survived'].astype('int64')

data.loc[data['is_train']==0,["PassengerId","Survived"]].to_csv('result_20220621_avg_nonWCG.txt',index=False,header=True)

# %%
temp.iloc[[ 21, 214, 339]]
# Out:
#      PassengerId  Survived  Survived3
# 21           913       1.0          0
# 214         1106       0.0          1
# 339         1231       1.0          0

# %%
data.loc[data['PassengerId'].isin([ 913,1106, 1231])]
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch    Fare  \
# 912           913       1.0       3   9.000000      0      1  3.1708
# 1105         1106       0.0       3  38.000000      4      2  7.7750
# 1230         1231       1.0       3  45.825002      0      0  7.2292
#
#       is_train Group_id  WC_count  ...  Age_range3  boy1  boy2  boy3  female1  \
# 912          0  noGroup       1.0  ...           0     0     0     1        0
# 1105         0  noGroup       1.0  ...           0     0     0     0        0
# 1230         0  noGroup       1.0  ...           1     0     0     1        0
#
#       female2  female3  male1  male2  male3
# 912         0        0      0      0      0
# 1105        0        1      0      0      0
# 1230        0        0      0      0      0
#
# [3 rows x 46 columns]

# %%
nonWCG_pred=model.predict(X_test)
data.loc[(data['is_train']==0)&(data['Sex']=='male')&(data['Group_id']=='noGroup'),'Survived']=nonWCG_pred

# %%
data['Survived']=data['Survived'].astype('int64')
data.loc[data['is_train']==0,["PassengerId","Survived"]].to_csv('result_20220622_WCGLgb.txt',index=False,header=True)
# pd.DataFrame(data=np.c_[list(range(892,1310)),data.loc[data['is_train']==0,"Survived"]],columns=["PassengerId","Survived"],dtype=np.int64).to_csv('result_20220621_WCGAndModel.txt',index=False,header=True)# 得分：0.73444

# %%
sex3=pd.read_csv("./result_20220622_WCGLgb.txt")
sex3WCG=pd.read_csv("./result_20220621_avg_nonWCG.txt")
temp=pd.concat([sex3WCG,sex3['Survived'].rename('Survived3')],axis=1)
np.where(temp['Survived']!=temp['Survived3'])# 4个pclass为1，2的boy预测为1
# Out:
# (array([ 21, 214, 339], dtype=int64),)

# %%
data.loc[data['PassengerId'].isin([ 913,1106, 1231])]
# Out:
#       PassengerId  Survived  Pclass                                    Name  \
# 912           913       0.0       3               Olsen, Master. Artur Karl
# 1105         1106       1.0       3  Andersson, Miss. Ida Augusta Margareta
# 1230         1231       0.0       3                   Betros, Master. Seman
#
#          Sex   Age  SibSp  Parch   Ticket    Fare Cabin Embarked  is_train  \
# 912      boy   9.0      0      1  C 17368  3.1708   NaN        S         0
# 1105  female  38.0      4      2   347091  7.7750   NaN        S         0
# 1230     boy   NaN      0      0     2622  7.2292   NaN        C         0
#
#        Title    Surname          Ticket_id Group_id  WC_count  WCSurvived
# 912   Master      Olsen  3-C 1736-3.1708-S  noGroup       1.0         NaN
# 1105    Miss  Andersson    3-34709-7.775-S  noGroup       1.0         NaN
# 1230  Master     Betros     3-262-7.2292-C  noGroup       1.0         NaN

# %%
temp.iloc[[ 21, 214, 339]]
# Out:
#      PassengerId  Survived  Survived3
# 21           913         1          0
# 214         1106         0          1
# 339         1231         1          0

# %%
data.loc[data['PassengerId'].isin([ 913,1106, 1231])]
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Fare  \
# 912           913         0       3     boy   9.0      0      1  3.1708
# 1105         1106         1       3  female  38.0      4      2  7.7750
# 1230         1231         0       3     boy   NaN      0      0  7.2292
#
#       is_train Group_id  ...  Age_range3  boy1  boy2  boy3  female1  female2  \
# 912          0  noGroup  ...           0     0     0     1        0        0
# 1105         0  noGroup  ...           0     0     0     0        0        0
# 1230         0  noGroup  ...           1     0     0     1        0        0
#
#       female3  male1  male2  male3
# 912         0      0      0      0
# 1105        1      0      0      0
# 1230        0      0      0      0
#
# [3 rows x 44 columns]

# %%
data.loc[data['PassengerId'].isin([ 913,1106, 1231])]
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  \
# 912           913         1       3   9.000000      0      1   3.1708
# 1016         1017         0       3  17.000000      0      1  16.1000
# 1230         1231         1       3  45.825002      0      0   7.2292
# 1267         1268         0       3  22.000000      2      0   8.6625
#
#       is_train Group_id  WC_count  ...  Age_range3  boy1  boy2  boy3  female1  \
# 912          0  noGroup       1.0  ...           0     0     0     1        0
# 1016         0  noGroup       1.0  ...           0     0     0     0        0
# 1230         0  noGroup       1.0  ...           1     0     0     1        0
# 1267         0  noGroup       1.0  ...           0     0     0     0        0
#
#       female2  female3  male1  male2  male3
# 912         0        0      0      0      0
# 1016        0        1      0      0      0
# 1230        0        0      0      0      0
# 1267        0        1      0      0      0
#
# [4 rows x 46 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 46 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   float64
#  3   Age          1046 non-null   float64
#  4   SibSp        1309 non-null   int64
#  5   Parch        1309 non-null   int64
#  6   Fare         1309 non-null   float64
#  7   is_train     1309 non-null   int64
#  8   Group_id     1309 non-null   object
#  9   WC_count     527 non-null    float64
#  10  WCSurvived   210 non-null    float64
#  11  Cabins       1309 non-null   int64
#  12  familyNum    1309 non-null   int64
#  13  has_family   1309 non-null   int64
#  14  CabinA       1309 non-null   Sparse[uint8, 0]
#  15  CabinB       1309 non-null   Sparse[uint8, 0]
#  16  CabinC       1309 non-null   Sparse[uint8, 0]
#  17  CabinD       1309 non-null   Sparse[uint8, 0]
#  18  CabinE       1309 non-null   Sparse[uint8, 0]
#  19  CabinF       1309 non-null   Sparse[uint8, 0]
#  20  CabinG       1309 non-null   Sparse[uint8, 0]
#  21  CabinT       1309 non-null   Sparse[uint8, 0]
#  22  CabinZ       1309 non-null   Sparse[uint8, 0]
#  23  EmbarkedC    1309 non-null   Sparse[uint8, 0]
#  24  EmbarkedQ    1309 non-null   Sparse[uint8, 0]
#  25  EmbarkedS    1309 non-null   Sparse[uint8, 0]
#  26  TitleMaster  1309 non-null   Sparse[uint8, 0]
#  27  TitleMiss    1309 non-null   Sparse[uint8, 0]
#  28  TitleMr      1309 non-null   Sparse[uint8, 0]
#  29  TitleMrs     1309 non-null   Sparse[uint8, 0]
#  30  TitleRare    1309 non-null   Sparse[uint8, 0]
#  31  Sexboy       1309 non-null   Sparse[uint8, 0]
#  32  Sexfemale    1309 non-null   Sparse[uint8, 0]
#  33  Sexmale      1309 non-null   Sparse[uint8, 0]
#  34  Age_range1   1309 non-null   Sparse[uint8, 0]
#  35  Age_range2   1309 non-null   Sparse[uint8, 0]
#  36  Age_range3   1309 non-null   Sparse[uint8, 0]
#  37  boy1         1309 non-null   Sparse[uint8, 0]
#  38  boy2         1309 non-null   Sparse[uint8, 0]
#  39  boy3         1309 non-null   Sparse[uint8, 0]
#  40  female1      1309 non-null   Sparse[uint8, 0]
#  41  female2      1309 non-null   Sparse[uint8, 0]
#  42  female3      1309 non-null   Sparse[uint8, 0]
#  43  male1        1309 non-null   Sparse[uint8, 0]
#  44  male2        1309 non-null   Sparse[uint8, 0]
#  45  male3        1309 non-null   Sparse[uint8, 0]
# dtypes: Sparse[uint8, 0](32), float64(5), int64(8), object(1)
# memory usage: 181.6+ KB
